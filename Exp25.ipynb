# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothireddy77/DSA0306---NLP/blob/main/Exp25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
#create OpenAI client
client=genai.Client(api_key="need to enter any api")
#Get prompt from user
prompt=input("Enter your prompt: ")
#Generate text using Gpt-3.5 Turbo Instruct
response =client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt,
)
print("\nGenerated text:")
print(response.text)
# Out:
# Enter your prompt: BMw.?
#
# Generated text:
# **BMW** (which stands for *Bayerische Motoren Werke*, or **Bavarian Motor Works**) is a German luxury automotive brand known worldwide for producing high-performance cars, SUVs, and motorcycles.
#
# Since your question is broad, what specifically would you like to know about BMW? Here are a few common topics:
#
# 1. **Model Lineup:**
#    * **Sedans/Coupes:** 2 Series, 3 Series, 5 Series, 7 Series, 8 Series.
#    * **SUVs (SAVs):** X1 through X7, plus the XM.
#    * **Roadsters:** Z4.
# 2. **BMW M (Performance Division):** High-performance track-tuned models like the M3, M4, M5, and X5 M.
# 3. **Electric Vehicles (BMW i):** All-electric models like the i4, i5, i7, and iX.
# 4. **Motorcycles:** BMW Motorrad (e.g., GS series, S1000RR).
# 5. **Buying/Maintenance Advice:** Reliability, common issues, or comparing specific models.
#
# Let me know what you'd like to explore!
